# %% [markdown]
# # Eksoplanet
#
# Predvidevamo, da ima večina zvezd svoja osončja. Ampak ker so tuja osončja daleč, v njih  pa po masi in izsevu močno dominira zvezda, je eksoplanete ali planete tujih osončij zelo težko odkriti in opazovati. Najbolj plodna metoda se zanaša na prehod planeta preko zvezde. Gre za neke vrste mrk, kjer planet zakrije majhen del zvezdine ploskve, zaradi česar se ji svetlost rahlo zmanjša. Ker so planeti veliko manjši od zvezd, je sprememba svetlosti tako majhna, da opazujemo lahko le velike planete, ki prekrijejo male zvezde. Potrebni so namenski teleskopi v vesolju, da lahko opazimo dogodek, ko planet podoben Zemlji prekrije zvezdo podobno Soncu. Ocenimo koliko se v takem primeru spremeni svetlost zvezde. Izračunajmo razmerje svetlobnega toka $F$, ki ga dobimo iz zvezde z radijem $R$ in svetlobnega toka $F_\mathrm{z}$, ki ga dobimo iz iste zvezde, ko jo zakrije planet z radijem $r$:
#
# $$\frac{F}{F_\mathrm{z}}=\frac{\pi R^2}{\pi R^2-\pi r^2}.$$
#
# Če za radij zvezde vstavimo radij Sonca $R=700\,000\ \mathrm{km}$ in za radij planeta radij Zemlje $r=6\,400\ \mathrm{km}$, dobimo razmerje svetlobnih tokov 1.000084, oziroma razliko 0.0084%. Z zemeljskimi teleskopi lahko rutinsko merimo spremembe svetlosti velikostnega reda 0.5%. Očitno Zemlji podobnih planetov v tej vaji ne bomo opazovali. Naše tarče bodo vroči jupitri (največji razred planetov) okoli pritlikavih zvezd (zvezd podobnih Soncu, najpogosteje še manjših od Sonca). Sprememba svetlosti zaradi prehoda planeta je v takih primerih nekaj procentov.
#
# <figure>
# <img src="transitgif2.gif" width="600"/>
# </figure>
#
# ## Opis vaje
#
# Izmed znanih eksoplanetov boste morali najti takšnega s prehodom preko zvezde na izbrano noč, ki je tudi primeren za opazovanje z našimi teleskopi. S teleskopom Zarja boste tekom noči merili svetlost matične zvezde, predivdoma dovolj časa, da boste opazovali vse faze prehoda. Slike boste obdelali in natančno izmerili svetlost zvezde na vseh posnetkih. Iz tako dobljene svetlobne krivulje boste izmerili osnovne parametre exoplaneta.
#
# Postopek obdelave slik bo enak tistemu v vaji Barvna slika. Spoznali boste algoritem imenovan aperturna fotometrija, s katerim boste lahko zelo natančno izmerili svetlost opazovane zvezde. S primerjavo svetosti nekaj zvezd v polju pa boste kompenzirali spreminjanje svetlosti zaradi atmosferskih in vremenskih vplivov. Spoznali boste tudi koncept magnitud, kar je količina s katero v astronomiji merimo svetlost objektov.

# %% [markdown]
# ## Opazovanja
#
# ### Inštrumenti
#
# Opazovali boste s Teleskopom ASA AZ800 (Zarja) in kamero C5A-150M. Na voljo boste imeli tudi standarden set barvnih filtrov.
#
# ### Planeti primerni za opazovanje
#
# Znanih je več kot 6000 eksoplanetov. Večina jih ni primernih za naša opazovanja. Na spletni strani [https://astro.swarthmore.edu/transits/](https://astro.swarthmore.edu/transits/) si lahko pripravimo efemeride (efemeride so napovedi astronomskih dogodkov) prehodov primernih za opazovanje. Nastavimo koordinate observatorija na Golovcu ($\phi=46.04^\circ$, $\lambda=14.53^\circ$), razpon želenih datumov in nekaj omejitev, da prikažemo le prehode primerne za opazovanje, na primer spremembo svetlosti vsaj 20 ppt (parts per thousand) in magnitudo 14, saj bi raje opazovali svetle zvezde, ki jim lahko bolj natančno pomerimo svetlost. Primer rezultatov poizvedbe za 7. april 2026 je prikazan spodaj.
#
# <figure>
# <img src="planet_efemeride.png" width="1200"/>
# <figcaption align = "center"> Efemeride za prehode planetov 7. aprila 2026. </figcaption>
# </figure>
#
# To noč lahko ujamemo le zadnji del prehoda planeta Qatar-9 b in prvi del prehoda planeta TOI-1259 A b. Opazujemo pa lahko celoten potek prehoda planeta Qatar-2 b, vključno z nekaj časa pred in po prekritju. Zvezda bo ta čas vedno več kot $30^\circ$ nad obzorjem, opazovanja ne bo motila Luna, prehod bo trajala 1 uro in 49 minut, pričakujemo padec svetlosti za 3.3%. To bi bil idealen objekt za opazovanje. Imeli pa bi dolgo noč, saj bi opazovanje zaključili ob petih zjutraj. Podobno primerne dogodke lahko najdemo tudi v veliko drugih nočeh.
#
# ### Pregled opazovanj
#
# V tej vaji opazujemo planet z imenom HAT-P-32 b. To je bil 32. planet odkrit v okviru madžarskega projekta HATNet leta 2011. HAT-P-32 je eno od imen zvezde okoli katere so odkrili planet. Eksoplanete poimenujejo z imenom zvezde z dodano črko, ki označuje zaporedje odkritih planetov v tistem osončju. "b" pomeni, da je bil to prvi planet odkrit v tem osončju (črko "a" spustimo, oziroma bi implicirala oznako za zvezdo). Planet kroži okoli zvezde, ki je rahlo masivnejša od Sonca. Okoli zvezde, na veliko večji oddaljenosti kot planet, kroži še temna pritlikava zvezda tipa M. Zvezdni sistem je od nas oddaljen 292 pc (950 ly).
#
# Podatki so bili posneti 23. novembra 2024 z malim teleskopm na observatoriju na Golovcu brez uporabe barvnega filtra. Od kalibracijskih posnetkov imamo na voljo 11 bias posnetkov, 15 dark posnetkov in 7 flat posnetkov. Me dopazovanjem HAT-P-32 pa smo dvakrat podaljšali ekspozicijsi čas, saj se je tekom noči vreme slabšalo.
#
# | Posnetek | št. posnetkov | ekspozicijski čas |
# | :--------- | :--- | :----- |
# | bias          | 11   | 0 s  |
# | dark          | 15    | 60 s  |
# | flat          | 7    | 10 s  |
# | HAT-P-32 b    | 139    | 30 $*$  |
# | HAT-P-32 b    | 56    | 45 $*$  |
# | HAT-P-32 b    | 101    | 60 $*$  |
#
# $*$ Posnetki istega polja so narejeni s tremi različnimi ekspozicijskimi časi
#
# <figure>
# <img src="HAT-P-32_b.png" width="1200"/>
# <figcaption align = "center"> Posnetek polja zvezd, kjer se nahaja HAT-P-32 b. </figcaption>
# </figure>
#
# Na strani [Aladin](https://aladin.cds.unistra.fr/AladinLite/?target=02%2004%2010.2774374568%2B46%2041%2016.212315084&fov=0.8) si lahko narišemo opazovano polje zvezd. Označena je tudi zvezda HAT-P-32, pridobimo pa lahko še informacije o drugih zvezdah v polju, vključno z njihovo svetlostjo. Primerjajte našo sliko in sliko iz Aladina in najdite zvezdo HAT-P-32 na naši sliki.

# %% [markdown]
# ## Obdelava posnetkov
#
# Tako kot v vaji Izdelava barvnega posnetka moramo posnetke najprej obdelat. Iz danih bias, dark in flat posnetkov bomo naredili povprečene bias, dark in flat posnetke. Vsi posnetki so bili narejeni z istim barvnim filtrom, tako da bo ta del obdelave tokrat malo krajši. Signal bias in dark posnetka bomo odšteli od 296 posnetkov zvezdnega polja. Te posnetke bomo nato še delili z normaliziranim flat posnetkom. Pri odštevanju dark posnetka bomo pazili še na različno dolge ekspozicijske čase.
#
# Združimo najprej vse bias posnetke v povprečen bias, dark posnetke v povprečen dark in flat posnetke v povprečen flat.

# %%
# %matplotlib inline
from astropy.io import fits # modul za delo s fits posnetki
import matplotlib.pyplot as plt # modul za risanje grafov
import numpy as np # modul za numerične operacije
import astroalign # modul za poravnavo astronomskih posnetkov
import glob # Modul za brskanje po mapah
from scipy import ndimage # modul z drugimi uporabnimi funkcijami, ki jih uporabljamo za analizo slik

# Seznam vseh bias posnetkov
biases =  glob.glob('podatki/HAT-P-32_b/BIAS/bias*.fits')

# Odprimo vse bias posnetke
biases_data = []
for bias in biases:
    image_data = fits.getdata(bias)
    biases_data.append(image_data)

# Naredimo mediano vseh bias posnetkov
bias_median = np.median(biases_data, axis=0)

# Shranimo posnetek kot fits file
hdu = fits.PrimaryHDU(bias_median)
hdu.writeto('podatki/HAT-P-32_b/BIAS/masterbias.fits', overwrite=True)



# Seznam vseh dark posnetkov
darks =  glob.glob('podatki/HAT-P-32_b/DARK/dark*.fits')

# Odprimo vse dark posnetke
darks_data = []
for dark in darks:
    image_data = fits.getdata(dark)
    # odstranimo dark posnetku vrednost biasa
    image_data = image_data - bias_median
    darks_data.append(image_data)

# Naredimo mediano vseh dark posnetkov
dark_median = np.median(darks_data, axis=0)

# Shranimo
hdu = fits.PrimaryHDU(dark_median)
hdu.writeto('podatki/HAT-P-32_b/DARK/masterdark.fits', overwrite=True)



# Seznam vseh flat posnetkov
flats = glob.glob('podatki/HAT-P-32_b/FLAT/flat*.fits')

# Odprimo vse flat posnetke v tem filtru
flats_data = []
for flat in flats:
    image_data = fits.getdata(flat)
    # odstranimo bias
    image_data=image_data - bias_median
    flats_data.append(image_data)

# Naredimo povprecje vseh flat posnetkov
flat_average = np.average(flats_data, axis=0)

# Normaliziramo flat posnetek 
flat_average_norm = flat_average / np.median(flat_average)

# Shranimo
hdu = fits.PrimaryHDU(flat_average_norm)
hdu.writeto('podatki/HAT-P-32_b/FLAT/masterflat.fits', overwrite=True)

# %% [markdown]
# Pri obdelavi posnetkov zvezdnega polja bomo morali biti pazljivi, saj z razliko od vaje Barvna slika, naši posnetki nimajo nujno isto dolgih ekspozicijskih časov kot dark posnetek. V dark posnetkih je zabeležen termični signal, kot ga pridobimo v (tem primeru) 60 s ekspoziciji. Posnetki zvezdnega polja, ki so narejeni s 30 s ekspozicijo imajo torej pol manj termičnega signala. Pri obdelavi posnetkov bomo to kompenzirali tako, da bomo iz glave vsake slike prebrali ekspozicijski čas in dark posnetek, preden ga odštejemo od posnetka, skalirali glede na razmerje z ekspozicijskim časom dotičnega posnetka zvezd.
#
# Odprimo torej vsako sliko zvezdnega polja, ji odštejmo bias, preberimo ekspozicijki čas, skalirajmo dark, ga odštejmo in na koncu delimo rezultat s flat posnetkom. Obdelane slike bomo shranili pod istim imenom z dodatno končnico <tt>.reduced</tt>.

# %%
# Seznam vseh posnetkov v doticnem filtru
images = glob.glob('podatki/HAT-P-32_b/*.fits')

exposure_time_dark = 60

for image in images:
    # Odpremo slike
    # Z opcijo header=True dobimo poleg podatkov še glavo, ki jo shranimo v svojo spremenljivko
    image_data, header = fits.getdata(image, header=True)

    # Iz glave preberemo ekspozicijski čas
    exposure_time_image = header['EXPTIME']

    # skaliramo dark
    dark_scaled = dark_median * (exposure_time_image / exposure_time_dark)

    # odstejemo bias in skaliran dark
    image_data = image_data - bias_median - dark_scaled

    # Delimo s flatom
    image_data = image_data / flat_average_norm

    # Shranimo obdelano sliko
    # V glavo objekata hdu, k iga shranjujemo, bomo dodali se informacijo o ekspozicijskem času in čas opazovanja
    hdu = fits.PrimaryHDU(image_data)
    hdu.header['EXPTIME'] = header['EXPTIME']
    hdu.header['DATE-AVG'] = header['DATE-AVG']
    hdu.writeto(image+'.reduced', overwrite=True)

# %% [markdown]
# Vseh 296 slik bomo poravnali, tako da bodo zvezde na vseh slikah na istem mestu. V tej vaji to ni nujno, saj nas zanima le svetlost zvezde na vsakem posnetku, kjerkoli na sliki pač je. Nam bo pa ta operacija olajšala naslednje korake. Ponovimo ukaz iz vaje Barvna slika. Poravnanim slikam bomo dodali končnico <tt>.aligned</tt>.

# %%
# Odprimo referenčno sliko
ref = fits.getdata('podatki/HAT-P-32_b/HAT-P-32 b_C_0000.fits.reduced')

# Naredimo seznam vseh slik
images = glob.glob('podatki/HAT-P-32_b/*.fits.reduced')

# stevilo slik za obdelat
N_images = len(images)

# Vsako sliko popravimo in shranimo pod novim imenom
# Stevec nam pove kako dalec je prisel ta korak obdelave
for n,image in enumerate(images):
    image_data, header = fits.getdata(image, header=True)

    image_aligned, _ = astroalign.register(image_data+1, ref+1, detection_sigma=5, max_control_points=30, min_area=4)
    print(n+1,'/', N_images, '  ', image)

    # Shranimo poravnano sliko
    # V glavo dodamo iste informacije kot v prejsnjem koraku
    hdu = fits.PrimaryHDU(image_aligned-1)
    hdu.header['EXPTIME'] = header['EXPTIME']
    hdu.header['DATE-AVG'] = header['DATE-AVG']
    hdu.writeto(image+'.aligned', overwrite=True)
# Out:
# 1 / 296    podatki/HAT-P-32_b/HAT-P-32 b_C_0178.fits.reduced
# 2 / 296    podatki/HAT-P-32_b/HAT-P-32 b_C_0144.fits.reduced
# 3 / 296    podatki/HAT-P-32_b/HAT-P-32 b_C_0158.fits.reduced
# 4 / 296    podatki/HAT-P-32_b/HAT-P-32 b_C_0105.fits.reduced
# 5 / 296    podatki/HAT-P-32_b/HAT-P-32 b_C_0255.fits.reduced
# 6 / 296    podatki/HAT-P-32_b/HAT-P-32 b_C_0020.fits.reduced
# 7 / 296    podatki/HAT-P-32_b/HAT-P-32 b_C_0006.fits.reduced
# 8 / 296    podatki/HAT-P-32_b/HAT-P-32 b_C_0025.fits.reduced
# 9 / 296    podatki/HAT-P-32_b/HAT-P-32 b_C_0127.fits.reduced
# 10 / 296    podatki/HAT-P-32_b/HAT-P-32 b_C_0142.fits.reduced
# 11 / 296    podatki/HAT-P-32_b/HAT-P-32 b_C_0147.fits.reduced
# 12 / 296    podatki/HAT-P-32_b/HAT-P-32 b_C_0239.fits.reduced
# 13 / 296    podatki/HAT-P-32_b/HAT-P-32 b_C_0086.fits.reduced

# %% [markdown]
# ## Analiza
#
# ### Fotometrija
#
# Procesu merjenja svetlosti objektov pravimo fotometrija. Konkretnemu postopku, ki ga bomo uporabili tukaj pa rečemo aperturna fotometrija. Z aperturno fotometrijo bomo izmerili svetlost zvezde HAT-P-32 in nekaj primerjalnih zvezd. Svetlost zvezde lahko predstavimo s količino signala, ki prihaja iz vseh pikslov, ki jih zaseda zvezda. Pri tem bomo računali še na to, da se lahko tekom noči spreminja svetlost ozadja (nebo siplje in seva nekaj svetlobe, ki jo prav tako zaznamo na mestu zvezde na sliki). Koliko je signala ozadja bomo izmerili na območju slike okoli zvezde.
#
# Tekom noči se lahko spreminja tudi vreme in prepustnost atmosfere (zvezda navidezno postane temnejša, če jo zakrije oblak ali pa se premakne nižje nad obzorje). To bomo kompenzirali tako, da bomo ob zvezdi, ki ji merimo svetlost, opazovali še nekaj drugih zvezd, ki (upamo) jih ta čas ne prekrije noben planet in imajo zato konstantno svetlost. Vse variacije svetlosti teh primerjalnih zvezd lahko apliciramo na izmerjeno svetlost naše osrednje zvezde in tako kompenziramo spreminjajoče se vremenske pogoje. Temu pristopu rečemo diferencialna fotometrija. Tudi v najlepših nočeh pričakujemo, da vreme in zemeljska atmosfera prispevata večji delež spreminjanja svetlosti kot prehod planeta preko zvezde.
#
# Algoritem aperturne fotometrije je sledeč:
#
#  * Na eni od slik najdemo koordinate zvezde, katere svetlost merimo in koordinate nekaj primerjalnih zvezd.
#  * Definiramo radij, znotraj katerega se nahaja ves signal zvezde. Signal iz pikslov znotraj radija seštejemo, da dobimo svetlost slike znotraj radija. Temu radiju rečemo apertura, kar da tej metodi ime.
#  * Definiramo kolobar (z notranjim in zunanjim radijem) okoli zvezde. Ta kolobar bo določal območje, kjer bomo izmerili svetlost neba kot povprečen signal pikslov znotraj kolobarja. Pazimo, da notranji radij kolobarja ni premajhen, da ne bi v kolobar zajeli signala zvezd.
#  * Povprečen signal ozadja pomnožimo s številom pikslo znotraj radija, ki določa signal zvezde in signala odštejemo.
#
# ### Magnitude
#
# V astronomiji svetlost objektov navadno podajamo z magnitudami. To je logaritemska skala za merjenje svetlosti. Razlogov, da preferiramo logaritemsko skalo imamo mnogo, od zgodovinskih do praktičnih. V tej nalogi z logaritemsko skalo prevedemo zadnji korak fotometrije iz deljenja svetlobnih tokov v odštevanje magnitud, kar je bolj praktično.
#
# Magnitude so definirane tako, da razmerju svetlobnih tokov 100 odgovarja razlika magnitud 5. Oziroma ena magnituda odgovarja faktorju svetlobnih tokov $\sqrt[5]{100}=2.512$. Na primer Sirij, najsvetlejša zvezda na nebu, ima magnitudo $m_\mathrm{Sirij}=-1.5$ (brez enot). Najtemnejše zvezde, ki jih lahko vidimo s prostim očesom iz centra Ljubljane so stokrat temnejše in imajo magnitudo $m=3.5$, torej so 5 magnitud temnejše od Sirija. Številka je v resnici večja, ampak večja magnituda pomeni temnejši objekt. Definirana je le razlika magnitud, ne pa izhodišče te skale. Za izhodišče lahko uporabimo več standardnih definicij, ampak za naše potrebe si ga lahko poljubno izberemo. V tej vaji namreč merimo samo spremembo svetlosti. Absolutna svetlost zvezde nas ne zanima. Če za izhodišče sistema določimo, da ima objekt s svetlobnim tokom $F_0$ magnitudo $m_0$, nam razliko magnitud in razmerje svetlobnih tokov določata enačbi
# $$ m - m_0 = -2.5 \log_{10} \left( \frac{F}{F_0} \right)\qquad\mathrm{in}\qquad \frac{F}{F_0}=10^{0.4(m-m_0)},$$
# kjer je $F$ svetlobni tok, ki mu odgovarja magnituda $m$.
#
# ### Fotometrija v praksi
#
# V prvem koraku definiramo položaje zvezd, velikost aperture in kolobarja. Da se prepričamo, da smo izbrali prave in smiselne številke, narišimo vse na eno od slik. Ker smo slike v zadnjem koraku obdelave poravnali med sabo, bodo koordinate zvezd na vseh slikah iste. Če slik ne bi poravnali, bi morali ta korak ponoviti za vsako sliko posebej.

# %%
# Definirajmo koordinate zvezd, ki jim zelimo pomerit svetlost. Prva na seznamu je HAT P 32 b, ostale zvezde poimenujemo s stevilko.
# Dodali smo tudi magnitude primerjalnih zvezd
stars = {'HAT-P-32 b': [1679, 1271, None],\
        '1': [2202, 1561, 10.419],\
        '2': [1884, 1272, 10.875],\
        '3': [1513, 1046, 12.223],\
        '4': [2186, 1182, 11.566],\
        '5': [1365, 1569, 11.240],\
        '6': [1356, 1380, 12.555],\
        '7': [1623, 840, 10.263],\
        '8': [1957, 717, 11.090]}

# Definirajmo obmocje (radij) znotraj katerega merimo signal zvezde
aperture = 5.0

# Definirajmo notranji in zunanji radij kolobarja znotraj katerega merimo signal ozadja
ring_inner = 10.0
ring_outer = 18.0

# Narisimo obmocja na prvo sliko. Ostale slike smo poravnali glede na prvo sliko in bi morale imeti zvezde na istih pozicijah.
image_data = fits.getdata('podatki/HAT-P-32_b/HAT-P-32 b_C_0000.fits.reduced.aligned')
plt.figure(figsize = (14, 11))
plt.imshow(image_data, vmin = 700, vmax = 3500, cmap = 'gray')

plt.xlim(1000,2500)
plt.ylim(550,1800)

for star in stars.keys():
    cx=stars[star][0]
    cy=stars[star][1]

    # apertura
    circle = plt.Circle((cx, cy), aperture, color='r', fill=False)
    plt.gca().add_patch(circle)

    # notranji radij kolobarja
    circle = plt.Circle((cx, cy), ring_inner, color='g', fill=False)
    plt.gca().add_patch(circle)

    # zunanji radij kolobarja
    circle = plt.Circle((cx, cy), ring_outer, color='g', fill=False)
    plt.gca().add_patch(circle)

    # tekst z oznako zvezde
    plt.text(cx, cy, '  '+star, ha='left', va='bottom', c='y')

# %% [markdown]
# Sedaj lahko izmerimo signal v pikslih znotraj definiranih apertur in kolobarjev. Najprej moramo najti piksle, ki ležijo znotraj apertur in kolobarjev. V tem primeru bodo to vsi piksli katerih center leži znotraj aperture ali kolobarja. Če bi bili bolj pedantni, bi lahko signal pikslov na robu območij skalirali glede na delež piksla, ki leži znotraj območja.
#
# Tako kot v vaji Barvni posnetek bomo izdelali matriko, ki ima velikost slike in vsak element podaja oddaljenost piksla od centra, ki definira koordinato zvezde. Piksle, ki ležijo v koncentričnih območjih lahko potem enostavno izberemo brez da bi rabili na vsakem posnetku za vsak piksel poiskati oddaljenost od centra zvezde. Matrike, ki imajo vrednost 0 za piksle, ki ne ležijo v pravem območju in 1 za piksle, ki ležijo znotraj aperture ali kolobarja dodamo v naš slovar lastnosti zvezd.

# %%
# Definirajmo matriko (isto velik okot sliko), ki oznacuje piksle, ki so znotraj radija aperture 
# in matriko za piksle, ki so znotraj kolobarja.
# To naredimo za vse zvezde, k inas zanimajo. Matrike dodamo v zgornji slovar.
# Dodamo se stevilo pikslov, ki so znotraj radija aperture.
for star in stars.keys():
    cx=stars[star][0]
    cy=stars[star][1]
    # tabela oddaljenosti od centra zvezde
    y, x = np.indices(image_data.shape)
    r = np.sqrt((x - cx)**2 + (y - cy)**2)
    
    # piksli, ki so znotraj aperture:
    labels_aperture = np.zeros(image_data.shape, dtype=int)
    labels_aperture[(r<aperture)]=1
    # stevilo pikslov znotraj aperture
    n_pixels=np.sum(labels_aperture)

    # piksli, ki so znotraj kolobarja
    labels_ring = np.zeros(image_data.shape, dtype=int)
    labels_ring[(r<ring_outer)&(r>ring_inner)]=1

    # dodajmo vse to v slovar
    stars[star].append(labels_aperture)
    stars[star].append(labels_ring)
    stars[star].append(n_pixels)

# %% [markdown]
# Vse imamo pripravljeno, da na vseh posnetkih zvezdnega polja izmerimo svetlost izbranih zvezd. Ker nas zanima spreminjanje svetlosti v času, bomo rezultate shranili v tabelo. Ena tabela naj vsebuje časen druga tabela izmerjene signale.
#
# Signal pikslov, ki so znotraj aperture seštejemo. Za signal pikslov, k iso znotraj kolobarja pa izračunamo mediano. Tako dobimo povprečen signal ozadja enega piksla, ki pa ni močno prizadet zaradi morebitne vključitve kake zvezde v kolobar. Če se je to zgodilo, zvezda pokvari signal le v manjšem delu pikslov in  ne vpliva na mediano. Od signala seštetega po pikslih znotraj aperture odštejemo signal ozadja, k ipa ga moramo pomnožiti s številom pikslov v aperturi.

# %%
# seznam vseh slik
images = glob.glob('podatki/HAT-P-32_b/*.fits.reduced.aligned')

# prostor za shranjevanje rezultatov
date = []
signal = []

# zanka po vseh slikah
for image in images:
    # odpremo posnetek
    image_data, header = fits.getdata(image, header=True)
    time_obs = header['DATE-AVG']

    # sem shranimo signale izmerjene za vse zvezde na enem posnetku
    signals = []

    # izracunamo signal znotraj aperture in kolobarja za vsako zvezdo
    for star in stars.keys():
        labels_aperture = stars[star][3]
        labels_ring = stars[star][4]
        n_pixels = stars[star][5]

        brightness_aperture = ndimage.sum(image_data, labels=labels_aperture)
        brightness_ring_per_pixel = ndimage.median(image_data, labels=labels_ring)

        signal_star = brightness_aperture - brightness_ring_per_pixel * n_pixels
        
        signals.append(signal_star)

    # shranimo datum/cas
    date.append(time_obs)
    # v prvo tabelo shranimo tabelo signalov vseh zvezd na tem posnetku
    signal.append(signals)

# %% [markdown]
# Narišimo rezultate. Najprej narišimo svetlost zvezde HAT-P-32. Signal, ki predstavlja svetlobni tok bomo preračunali v magnitude. Tabel s časi, ki sedaj podaja čas kot string pa bomo morali prevest v format, ki je razumljiv modulom ,k ijih uporabljamo za risanje grafov in analizo podatkov.

# %%
# spremenimo sezname z rezultati v numpy array, ker je z njimi lazje delat
date=np.array(date)
signal=np.array(signal)

# prevedimo seznam datumov in casov v format, ki ga bo lahko prebral matplotlib
# uporabimo knjiznico astropy in prevedimo format casa
from astropy.time import Time
date_dt = Time(date)

# Preracunajmo signale v magnitude
# Izbira izhodisca je poljubna
zero_point = 1e9
signal_mag = -2.5 * np.log10(signal/zero_point)

# Narisimo magnitudo zvezde HAT-P-32
# date_dt.plot_date vrne cas, ki je razumljiv matplotlibu
plt.scatter(date_dt.plot_date, signal_mag[:,0], s = 4, lw = 0);
plt.xlabel('Čas (UTC)');
plt.ylabel('$m$ (nekalibrirana)');

# Vecja stevilka za magnitudo pomeni temnejso zvezdo. Dajmo zato obrnit y skalo tako, da nizje pomeni temneje in visje svetleje
plt.ylim(11,8)

# Polepsajmo format zapisa datuma z uro in minutami
import matplotlib.dates as mdates
fmt = mdates.DateFormatter("%H:%M")
plt.gca().xaxis.set_major_formatter(fmt)
plt.gcf().autofmt_xdate()

# %% [markdown]
# Vidimo, da je svetlobna krivulja zelo kaotična. Nobene sledi ni o signalu prehoda planeta. Razlog, da magnituda postaja tekom opazovanja temnejša je, da je zvezda zahajala in je zato vedno več svetlobe absorbirala atmosfera. Ob tem se je tudi slabšalo vreme, kar je dodatno potemnilo zvezdo. Spremenljivo vreme vidimo kot občasne padce svetlosti, ko je zvezdo zakril kak manjši oblak. Dva vertikalna skoka svetlosti sta umetna in se zgodita, kjer se je spremenil ekspozicijski čas. Daljši ekspozicijski čas pomeni več zbrane svetlobe, močnejši signal in posledično nižjo magnitudo.
#
# Narišimo še svetlobno krivuljo za vse primerjalne zvezde. Pričakujemo, da bodo imele podobno obliko, saj so bile takisto prizadete zaradi atmosferske absorpcije, vremena in spremembe ekspozicijskega časa.

# %%
# Narisimo magnitudo primerjalnih zvezd
plt.scatter(date_dt.plot_date, signal_mag[:,1], s = 4, lw = 0, label = '1')
plt.scatter(date_dt.plot_date, signal_mag[:,2], s = 4, lw = 0, label = '2')
plt.scatter(date_dt.plot_date, signal_mag[:,3], s = 4, lw = 0, label = '3')
plt.scatter(date_dt.plot_date, signal_mag[:,4], s = 4, lw = 0, label = '4')
plt.scatter(date_dt.plot_date, signal_mag[:,5], s = 4, lw = 0, label = '5')
plt.scatter(date_dt.plot_date, signal_mag[:,6], s = 4, lw = 0, label = '6')
plt.scatter(date_dt.plot_date, signal_mag[:,7], s = 4, lw = 0, label = '7')
plt.scatter(date_dt.plot_date, signal_mag[:,8], s = 4, lw = 0, label = '8')
plt.xlabel('Čas (UTC)')
plt.ylabel('$m$ (nekalibrirana)');
plt.legend()

plt.ylim(11.5,7.5)

plt.gca().xaxis.set_major_formatter(fmt)
plt.gcf().autofmt_xdate()

# %% [raw]
# Iz znanih magnitud teh primerjalnih zvezd in s predpostavko, da je njihova magnituda konstanta, lahko izračunamo popravke, ki bodo kompenzirali vse telurične hibe našega opazovanja. Narišimo najprej popravke in raziščimo ali so konsistentni za vse primerjalne zvezde. Popravek enostavno izračunamo kot razliko med izmerjeno in znano magnitudo.

# %%
# Izracunamo normalizacijo preko znane magnitude primerjalnih zvezd
corr_1 = signal_mag[:,1] - stars['1'][2]
corr_2 = signal_mag[:,2] - stars['2'][2]
corr_3 = signal_mag[:,3] - stars['3'][2]
corr_4 = signal_mag[:,4] - stars['4'][2]
corr_5 = signal_mag[:,5] - stars['5'][2]
corr_6 = signal_mag[:,6] - stars['6'][2]
corr_7 = signal_mag[:,7] - stars['7'][2]
corr_8 = signal_mag[:,8] - stars['8'][2]

# Narisimo popravke
plt.scatter(date_dt.plot_date, corr_1, s = 4, lw = 0, label = '1')
plt.scatter(date_dt.plot_date, corr_2, s = 4, lw = 0, label = '2')
plt.scatter(date_dt.plot_date, corr_3, s = 4, lw = 0, label = '3')
plt.scatter(date_dt.plot_date, corr_4, s = 4, lw = 0, label = '4')
plt.scatter(date_dt.plot_date, corr_5, s = 4, lw = 0, label = '5')
plt.scatter(date_dt.plot_date, corr_6, s = 4, lw = 0, label = '6')
plt.scatter(date_dt.plot_date, corr_7, s = 4, lw = 0, label = '7')
plt.scatter(date_dt.plot_date, corr_8, s = 4, lw = 0, label = '8')

# Narisimo se povprecje popravkov
plt.scatter(date_dt.plot_date, np.average([corr_1, corr_2, corr_3, corr_4, corr_5, corr_6, corr_7, corr_8], axis=0), s = 4, lw = 0, c = 'k', label = 'avg')

plt.xlabel('Čas (UTC)')
plt.ylabel('$\\Delta m$')
plt.legend()

plt.ylim(-0.3, -3.3)

plt.gca().xaxis.set_major_formatter(fmt)
plt.gcf().autofmt_xdate()

# %% [markdown]
# Magnitudo zvezde HAT-P-32 lahko popravimo, tako da od njene izmerjene magnitude odštejemo popravek, ki smo ga izračunali iz magnitude primerjalnih zvezd.

# %%
# Narisimo magnitudo zvezde HAT-P-32 z odstetim popravkom
plt.scatter(date_dt.plot_date, signal_mag[:,0] - np.average([corr_1, corr_2, corr_3, corr_4, corr_5, corr_6, corr_7, corr_8], axis = 0), s = 8, lw = 0);
plt.xlabel('Čas (UTC)');
plt.ylabel('$m$ (C filter)');

plt.ylim(11.02, 10.93)

plt.gca().xaxis.set_major_formatter(fmt)
plt.gcf().autofmt_xdate()

# %% [markdown]
# Lepo vidimo padec svetlosti, ki se začne okoli časa 16:50. Zaradi manj natančne fotometrije je konec prehoda slabše opazen. Zgodi se okoli časa 19:50.
#
# ### Modeliranje svetlobne krivulje
#
# Iz izmerjene svetlobne krivulje lahko izračunamo razmerje med velikostjo planeta in zvezde ter razmerje med veliko polosjo orbite planeta in velikostjo zvezde. Prvo smo pokazali že v uvodu, slednje pa ob predpostavki krožnih orbit poravnanih z ravnino opazovalca dobimo iz razmerja obhodnega časa in trajanja prehoda:
# $$ \Delta t =\frac{P}{2\pi a} 2 R,$$
# kjer je $\Delta t$ čas trajanja prehoda, $P$ perioda, ki jo izmerimo iz daljših opazovanj (torej čas med dvema prehodoma), $a$ je velika polos orbite planeta, $R$ pa je radij zvezde.
#
# Na obliko svetlobne krivulje vpliva še čas, ko planet zakriva le rob zvezde. To v svetlobni krivulji vidimo kot počasno padanje in naraščanje sija na levi in desni strani minimuma svetlosti. Koliko časa ta faza traja in kakšna je oblika padanja in naraščanja sija je odvisno od velikosti zvezde in planeta ter od oblike orbite. Predvsem je pomembna še inklinacija orbite, saj ni nujno da planet prečka središče zvezdne ploskvice.
#
# Če je planet na ekscentrični eliptični orbiti na čas trajanja prehoda vpliva še orientacija orbite. Bližje zvezde se planet giblje hitreje, dlje od je pa počasneje. Del orbite, ki leži med nami in zvezdo ima hitrost nekje med obema tema skrajnostima.
#
# Ko cela ploskvica planeta prekriva ploskvico zvezde, je količina zastrte svetlobe odvisna tudi od površinske svetlosti zvezde, ki jo podaja funkcija robne zatemnitve. To vidimo kot spreminjanje minimuma svetlobne krivulje v obliki črke U. Iz tega lahko izmerimo robno zatemnitev, ali pa predpostavimo model robne zatemnitve, s čimer lažje ocenimo inklinacijo orbite planeta.
#
# Našteli smo nekaj parametrov, ki vplivajo na obliko svetlobne krivulje. V praksi jih ne merimo neposredno iz časov prehoda in globin svetlobne krivulje, ampak izdelamo model krivulje, ki ga prilagajamo na naše meritve. Fizika kompletnega modela je preprosta, geometrija pa ne. Geometrija je izpeljana v članku [K. Mandel & E. Agol: *_Analytic Light Curves for Planetary Transit Searches_*, AJ, 580, 2 (2002)](https://ui.adsabs.harvard.edu/abs/2002ApJ...580L.171M/abstract). Model iz tega članka lahko v pythonu narišemo z modulom <tt>batman</tt>, zato se tukaj ne bomo poglabljali v analitično obliko svetlobne krivulje.
#
# Z modulom <tt>batman</tt> lahko izdelamo model svetlobne krivulje, ki jo pričakujemo pri danih parametrih. V spodnjem primeru uporabim podatke iz literature, raze nsrednjega časa prehoda, ki sem ga nastavil glede na čas izmerjen iz našega opazovanja. Vidimo, da naša meritev le ni tako slaba in lepo sledi modelu iz literature. Poigrajte se s parametri modela in raziščite kako vplivajo na obliko svetlobne krivulje.

# %%
# Narisimo se enkrat naso svetlobno krivuljo. 
# Enote na x osi naj bodo tokrat decimalni dnevi, saj v taki obliki model svetlobne krivulje sproducira batman
plt.scatter(date_dt.mjd, signal_mag[:,0]-np.average([corr_1, corr_2, corr_3, corr_4, corr_5, corr_6, corr_7, corr_8], axis=0), s=8, lw=0);
plt.xlabel('Čas (decimalen dan)');
plt.ylabel('$m$ (C filter)');

plt.xlim(min(date_dt.mjd), max(date_dt.mjd))
plt.ylim(11.03, 10.93)

# Z modulom batman izdelamo model
import batman

# Naredimo objekt, v katerem so zapisani parametri planeta, zvezde in orbite
params = batman.TransitParams()

# V objekt dodamo parametere
params.t0 = 60637.767                  # cas sredine prehoda v decimalnih dnevih
params.per = 2.15                      # orbitalna perioda v decimalnih dnevih
params.rp = 0.148                      # radij planeta v enotah radija zvezde (razmerje r/R)
params.a = 5.4                         # velika polos orbite planeta v enotah radija zvezde (razmerje a/R)
params.inc = 88.8                      # inklinacija orbite planeta v stopinjah (90 stopinj pomeni poravnano z Zemljo)
params.ecc = 0.04                      # ekscentricnost orbite planeta
params.w = 96.                         # dolzina periastrona v stopinjah
params.u = [0.6]                       # koeficient robne zatemnitve (ali vec koeficientov, ce ne uporabimo linearnega modela)
params.limb_dark = "linear"            # model robne zatemnitve

# Definiramo obmocje casov v katerih bomo narisali model
t = np.linspace(min(date_dt.mjd), max(date_dt.mjd), 100)

# izracunamo model
m = batman.TransitModel(params, t)
# modeliran svetlobni tok prepisemo v novo spremenljivko
flux = m.light_curve(params)

# prevedimo svetlobni tok v magnitude
# umeritev dodamo sami, saj model ne ve kako svetlo zvezdo smo opazovali
mag_model=-2.5*np.log10(flux)+10.997

plt.plot(t,mag_model, c='C1');

# %% [markdown]
# ## Vprašanja
#
#  * Koliko mora biti velik kolobar, ki nam definira območje merjenja svetlosti neba v primerjavi z radijem, ki definira območje signala zvezde?
#  * Kakšnemu razmerju svetlobnih tokov odgovarjata razliki magnitud $\Delta m=0.01$ in $\Delta m=0.001$?
#  * Recimo, da smo opazovali prehod, ki pa se ni zgodila ob napovedanem času, ampak 15 minut prepozno. Kaj lahko sklepamo o takem tujem osončju?
#  * Okoli zvezde HAT-P-32, ki ima magnitudo 11.2 kroži še pritlikavka tipa M, ki je 3.5 magnitude temnejša. Zvezd z našim teleskopom ne moremo razločit in ju na slikah vidimo kot en objekt. Kolikšen delež signala v našo aperturo prispeva pritlikavka tipa M?

# %%
# Pocistimo za sabo
# Izbrisimo vse razen zacetnih slik

import os

os.remove('podatki/HAT-P-32_b/BIAS/masterbias.fits')
os.remove('podatki/HAT-P-32_b/DARK/masterdark.fits')
for f in glob.glob('podatki/HAT-P-32_b/FLAT/masterflat*.fits'):
    os.remove(f)
for f in glob.glob('podatki/HAT-P-32_b/*.reduced'):
    os.remove(f)
for f in glob.glob('podatki/HAT-P-32_b/*.aligned'):
    os.remove(f)
del date
del signal
